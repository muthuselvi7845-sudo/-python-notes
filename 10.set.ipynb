# %% [markdown]
# # set

# %% [markdown]
# ## Unordered
# ## Duplicates Not Allowed

# %%
k={1,1,1,2,2,1,1}
k
# Out:
# {1, 2}

# %%
myset = {"apple",89,"banana", "cherry", False, 1,True,0,5,9,90,8,90}
myset
# Out:
# {1, 5, 8, 89, 9, 90, False, 'apple', 'banana', 'cherry'}

# %%
print(len(myset))
# Out:
# 10

# %%
set={"babana",0,False,True,1,2,2,5}
print(len(set))
# Out:
# 5

# %%
list=["hello",1,2,2,2,3,454,"hi"]
Set=set(list)
Set
# Out:
# {1, 2, 3, 454, 'hello', 'hi'}

# %%
myset = {"apple", "banana", "cherry"}

for x in myset:
  print(x)

# %%
myset = {1,1,1,1,2,3,3,4}
myset

# %% [markdown]
# # add

# %%
myset = {"apple", "banana", "cherry"}

myset.add(1)

print(myset)
# Out:
# {1, 'cherry', 'banana', 'apple'}

# %%
myset = {"apple", "banana", "cherry"}
myset1 = {"pineapple", "mango", "papaya"}

myset.update(myset1)

print(myset)
# Out:
# {'cherry', 'mango', 'papaya', 'pineapple', 'banana', 'apple'}

# %%
myset = {"apple", "banana", "cherry"}
mylist = {"kiwi", "orange","apple"}

myset.update(mylist)

print(myset)
# Out:
# {'orange', 'cherry', 'kiwi', 'apple', 'banana'}

# %% [markdown]
# # remove

# %%
myset = {"apple", "banana", "cherry"}

myset.remove("banana")

print(myset)

# %%
myset = {"apple", "banana", "cherry"}

myset.discard("banana")

print(myset)
# Out:
# {'cherry', 'apple'}

# %%
myset = { "banana","apple","hji",9,78,"hello"}
print(myset)
x = myset.pop()

print(x)

print(myset)
# Out:
# {'hji', 9, 'apple', 'banana', 78, 'hello'}
# hji
# {9, 'apple', 'banana', 78, 'hello'}

# %%
myset = {"apple", "banana", "cherry"}
myset.clear()
print(myset)
del myset
myset
# Out:
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 print(myset)
#       4 del myset
# ----> 5 myset
#
# NameError: name 'myset' is not defined
